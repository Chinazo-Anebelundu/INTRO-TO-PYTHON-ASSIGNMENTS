# %%
#Write a program that prints the numbers from 1 to 100.
#But for multiples of three print “Multiples of 3” instead of the number
#and for the multiples of five print “Multiples of 5”.
#For numbers which are multiples of both three and five print “Multiples of 3 and 5”.

for x in range(1, 101):
    if x % 3 == 0 and x % 5 == 0:
        print("Multiples of 3 and 5")
    
    elif x % 3 == 0:
        print("Multiples of 3")
    
    elif x % 5 == 0:
        print("Multiples of 5")
        
    else:
        print(x)
# Out:
# 1
# 2
# Multiples of 3
# 4
# Multiples of 5
# Multiples of 3
# 7
# 8
# Multiples of 3
# Multiples of 5
# 11
# Multiples of 3
# 13
# 14
# Multiples of 3 and 5
# 16
# 17
# Multiples of 3
# 19
# Multiples of 5
# Multiples of 3
# 22
# 23
# Multiples of 3
# Multiples of 5
# 26
# Multiples of 3
# 28
# 29
# Multiples of 3 and 5
# 31
# 32
# Multiples of 3
# 34
# Multiples of 5
# Multiples of 3
# 37
# 38
# Multiples of 3
# Multiples of 5
# 41
# Multiples of 3
# 43
# 44
# Multiples of 3 and 5
# 46
# 47
# Multiples of 3
# 49
# Multiples of 5
# Multiples of 3
# 52
# 53
# Multiples of 3
# Multiples of 5
# 56
# Multiples of 3
# 58
# 59
# Multiples of 3 and 5
# 61
# 62
# Multiples of 3
# 64
# Multiples of 5
# Multiples of 3
# 67
# 68
# Multiples of 3
# Multiples of 5
# 71
# Multiples of 3
# 73
# 74
# Multiples of 3 and 5
# 76
# 77
# Multiples of 3
# 79
# Multiples of 5
# Multiples of 3
# 82
# 83
# Multiples of 3
# Multiples of 5
# 86
# Multiples of 3
# 88
# 89
# Multiples of 3 and 5
# 91
# 92
# ...

# %%
#Write a program that prints out the sum of values between 1 and 100.
sum = 0
for n in range(1, 100):
    sum += n
    print(sum)
print("\n" "This is the cumulative sum", sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
#
# This is the cumulative sum 4950

# %%
#Write a Python program to convert temperatures to and from celsius, fahrenheit.
#[Formula : c/5 = f-32/9 [ where c = temperature in celsius and f = temperature in fahrenheit] 

#FROM CELSIUS TO FAHRENHEIT


C  = float(input("What degree in Celsius?"))

F = 1.8 * C + 32

print(C, "Degree in Celsius = ", F, "Degree in Fahrenheit")
# Out:
# What degree in Celsius? 58
# 58.0 Degree in Celsius =  136.4 Degree in Fahrenheit

# %%
#Write a Python program to convert temperatures to and from celsius, fahrenheit.
#[Formula : c/5 = f-32/9 [ where c = temperature in celsius and f = temperature in fahrenheit] 

#FROM FAHRENHEIT TO CELSIUS


F = float(input("What degree in Fahrenheit"))

C = (F - 32) / 1.8

print(F, "Degree in Fahrenheit = ", C, "Degree in Celsius")
# Out:
# What degree in Fahrenheit 35.3
# 35.3 Degree in Fahrenheit =  1.8333333333333317 Degree in Celsius

# %%
#ANOTHER METHOD

#Write a Python program to convert temperatures to and from celsius, fahrenheit.
#[Formula : c/5 = f-32/9 [ where c = temperature in celsius and f = temperature in fahrenheit] 

#FROM CELSIUS TO FAHRENHEIT


C  = float(input("What degree in Celsius?"))

if C > 0:
    print("Fahrenheit =", 1.8 * C + 32)
elif C < 0:
    print ("Fahrenheit =", 1.8 * C + 32)
else:
    print("Fahrenheit =", 1.8 * C + 32)
# Out:
# What degree in Celsius?-45
# Fahrenheit = -49.0

# %%
#Write a Python program to convert temperatures to and from celsius, fahrenheit.
#[Formula : c/5 = f-32/9 [ where c = temperature in celsius and f = temperature in fahrenheit] 

#FROM FAHRENHEIT TO CELSIUS


F  = float(input("What degree in Fahrenheit?"))

if F > 0:
    print("Celsius =", (F - 32) / 1.8)
elif F < 0:
    print ("Celsius =", (F - 32) / 1.8)
else:
    print("Celsius =", (F - 32) / 1.8)
# Out:
# What degree in Fahrenheit?63
# Celsius = 17.22222222222222
